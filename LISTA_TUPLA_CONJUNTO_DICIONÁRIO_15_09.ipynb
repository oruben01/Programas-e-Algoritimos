# %% [markdown]
# <a href="https://colab.research.google.com/github/oruben01/Programas-e-Algoritimos/blob/main/LISTA_TUPLA_CONJUNTO_DICION%C3%81RIO_15_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
alunos = ["Letícia", "Anderson", "Marcos"]
alunos.remove("Letícia")
print (alunos)
# Out:
# ['Anderson', 'Marcos']

# %%
alunos = ["Letícia", "Anderson", "Marcos"]
alunos.append ("Lívia")
print (alunos)
# Out:
# ['Letícia', 'Anderson', 'Marcos', 'Lívia']

# %%
aluno = ("Ana", 17, "Informática")
print (aluno[2]) #posição
# Out:
# Informática
