# %% [markdown]
# <a href="https://colab.research.google.com/github/oruben01/Programas-e-Algoritimos/blob/main/EXERC%C3%8DCIOS_22_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercício 1 DICIONÁRIOS

aluno = {
    "nome": "Ana",
    "idade": 17,
    "curso": "Informática"
}

print(aluno)
# Out:
# {'nome': 'Ana', 'idade': 17, 'curso': 'Informática'}

# %%
# Exercício 2 DICIONÁRIOS

aluno = {
    "nome": "Ana",
    "idade": 17,
    "curso": "Informática"
}

print(aluno["nome"])
print(aluno["idade"])
print(aluno["curso"])
# Out:
# Ana
# 17
# Informática

# %%
# Exercício 3 DICIONÁRIOS

produto = {
    "nome": "Teclado" ,
    "preço": 150.00,
    "estoque": 10
}

produto["preço"] = 120.00
print(produto)
# Out:
# {'nome': 'Teclado', 'preço': 120.0, 'estoque': 10}

# %%
# Exercício 4 DICIONÁRIOS

aluno = {
    "nome": "Ruben" ,
    "idade": 16
}
aluno["curso"] = "Mecatrônica"
print(aluno)
# Out:
# {'nome': 'Ruben', 'idade': 16, 'curso': 'Mecatrônica'}

# %%
# Exercício 5 DICIONÁRIOS

filme = {
    "título":
    "Homem Aranha" ,
    "ano": 2002 ,
    "gênero": "Ação e Aventura" ,
    "nota": 8.0 }

print(filme["título"])
print(filme["ano"])
print(filme["gênero"])
print(filme["nota"])
# Out:
# Homem Aranha
# 2002
# Ação e Aventura
# 8.0

# %%
# Exercício 1 CONJUNTO

numeros = {1, 2, 3, 4, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
# Exercício 2 CONJUNTO

numeros = {1, 2, 2, 3, 3, 4, 5, 5}
print(numeros)
# Out:
# {1, 2, 3, 4, 5}

# %%
# Exercício 3 CONJUNTO

frutas = {"maça", "banana", "laranja"}
frutas.add("morango")
print(frutas)
# Out:
# {'laranja', 'morango', 'banana', 'maça'}

# %%
# Exercício 4 CONJUNTO

cores = {"vermelho", "azul", "verde", "amarelo"}
cores.remove("verde")
print(cores)
# Out:
# {'amarelo', 'vermelho', 'azul'}

# %%
# exercício 5 CONJUNTO

nomes = ["Yris", "Luna", "Luna", "Maitê", "Yris", "Ravi", "Gael", "Theo", "Theo"]
nomes_conjunto = set(nomes)
print(nomes_conjunto)
