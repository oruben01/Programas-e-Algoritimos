# %% [markdown]
# <a href="https://colab.research.google.com/github/oruben01/Programas-e-Algoritimos/blob/main/Exerc%C3%ADcios_LISTAS_e_TUPLA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Exercício 1 LISTA

frutas = ["Maçã", "Banana", "Uva"]
frutas.append("Laranja")
print(frutas)
# Out:
# ['Maçã', 'Banana', 'Uva', 'Laranja']

# %%
# Exercício 2 LISTA

nomes = ["Rebeca", "Guilherme", "Melissa", "Kyara"]
print(nomes[0])
print(nomes[1])
print(nomes[3])
# Out:
# Rebeca
# Guilherme
# Kyara

# %%
# Exercício 3 LISTA

cores = ["vermelho", "azul", "verde"]
cores[1] = "amarelo"
print(cores)
# Out:
# ['vermelho', 'amarelo', 'verde']

# %%
# Exercício 4 LISTA

alunos = ["Nicolas", "Wendel", "Pyetra"]
alunos.append("Petros")
print(alunos)
# Out:
# ['Nicolas', 'Wendel', 'Pyetra', 'Petros']

# %%
# Exercício 5 LISTA

animais = ["cachorro", "gato", "coelho", "passarinho"]
animais.remove("coelho")
print(animais)
# Out:
# ['cachorro', 'gato', 'passarinho']

# %%
# ==============================================================================

# %%
# Exercício 1 TUPLAS

meses = ("Janeiro", "Fevereiro", "Março", "Abril")
print(meses)
# Out:
# ('Janeiro', 'Fevereiro', 'Março', 'Abril')

# %%
# Exercício 2 TUPLAS

numeros = (10, 20, 30, 40, 50)
print(numeros[0])
print(numeros[2])
print(numeros[4])
# Out:
# 10
# 30
# 50

# %%
# Exercício 3 TUPLAS

aluno = ("Ana", 17, "Informática")
print(aluno[0])
print(aluno[1])
print(aluno[2])
# Out:
# Ana
# 17
# Informática

# %%
# Exercício 4 TUPLA

cores = ("vermelho", "azul", "verde")

cores[1] = "amarelo"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_508/55444335.py in <cell line: 0>()
#       3 cores = ("vermelho", "azul", "verde")
#       4
# ----> 5 cores[1] = "amarelo"
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Exercício 5 TUPLAS

numeros = (2, 4, 2, 6, 2, 8, 10)
quantidade = numeros.count(2)
print(quantidade)
# Out:
# 3
